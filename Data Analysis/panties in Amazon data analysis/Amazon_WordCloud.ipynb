# %% [markdown]
# # Amazon_WordCloud

# %%
import pandas as pd 

df = pd.read_csv('each_description_review.csv')

df.columns 

df['review_text']

text_list = df['review_text'].tolist()

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
# example_sent = "This is a sample sentence, showing off the stop words filtration."
  
len(text_list)  # 2533

text =" "

for i, sen in enumerate(text_list):
    text += str(sen)
    #print(i, sen, type(sen))
    
text
# Out:
# ' First off, male user here. I have purchased all the colors offered and other sofishie panties and these are by far my favorite. The fit is perfect, I ordered medium and I have a 32” waist. I love the quality, how they feel and how they make my ass look. Totally recommend.Sexy look, but didn’t notice the brand until she shouted it from the bathroom, LOL. Whoever named this product had one job and failed miserably! Hahahaha “So fishie” isn’t exactly a thought you wanna associate with women’s undies. Just saying......These are really cute and sexy. I wouldn’t wear them every day but as a sexy date night panty they work well. The lace is elastic-y and feels like it could rip with rough handling, but I’m not sure what else you’d expect with all over lace panties.I have a 32” waist and 45” hips. I wear 12/14 jeans and the large fits but is just a bit too tight. An XL might fit a little better, but I have a similar pair from the same brand and the XL is just on the loose side.The shape of these panties is very flattering, though they gap in a strange place because the criss-cross in the back is a teensy bit loose. They\'re awkward to keep up, but I like the way they look and the price was too good to resist. Boyfriend loves \'em, of course.I ordered the small no we’re did it day runs big or give a number size to match they were very big more like at least a medium wanted them for a trip so was disappointedThese panties are so beautiful! However I wear a small and ordered a small and this was definitely more a m or a m/l. I’m sure that one of my friends with a bugger butt than me we will enjoy them when I gift it to themVery sexy and nice material. Was surprised it was a lil big.Product is really sexy but a lil on the big side.. Ordered a small and fits like a large.. Maybe for a lil bigger woman this product would fit niceGood ass-ortmentI’m kind of a Victoria Secret snob, but I took a chance and ordered the 20 pack of undies. One of my best purchases on Amazon to date! I received a variety of colors/materials and they honestly exceeded my expectations. There are only a few pair that I’m not crazy about, but that’s pretty good for not having personally selected them. For reference I ordered a L, I’m 5’7” and around 180 lbs (hourglass) and I wear a size 10 jean.Some of the numeric sizing is weird on the tags, but like the description says, just ignore that! They all seem to be about the same size. Will purchase again! (Pics included)I’m 5’5, 125lbs. I wear a 4/5 pants which is pretty much a halfway size (Small is too tight and Medium is too big). I ordered panty size Small and probably should have ordered a medium but I’m happy with my purchase. They’re adorable and I plan to purchase again.I bought these items based almost entirely on the positive reviews, so it only seemed fair to leave my own :) I received my panties (11 pairs) promptly, and they arrived neatly laid out in a reusable plastic pouch. All of my pairs were thongs or g-strings; unlike other reviewers I received no boy shorts or bikinis. Every pair was sized well (I ordered up to a 2xl, or a 9, from my usual 8), even a little loose on a pair or two. The seller is definitely paying attention to actual, not just listed size.I purchased these mainly because hubby had a sudden desire to see more g\'s, after a decade of liking other styles. And this order didn\'t disappoint. I liked 10/11 pairs, and even the last pair was cute, just a little bright for me. There\'s a pair of really lovely black lace g\'s, a couple of matching lace thongs (different colors, same panties), an adorable see-through pair of white with black butterflies, and several other cute lacey pairs.I will absolutely order this pack again, maybe even trying different styles.Thanks to the seller for the great variety and fit!I am a big girl. I’m 5’4 and weigh 215. I ordered extra large and they were pretty big. I could have gotten away with a large. But the variety and quality, I absolutely loved!!! So many  ...

# %%
stop_words = list(stopwords.words('english')) 
add_list = ['The','the','’',',','I','\'','!','.',"n't",')','(',"'m",'...',"''","'s",'It','5']
stop_words = stop_words + add_list
  
word_tokens = word_tokenize(text) 
  
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 
  
print(word_tokens) 
print(filtered_sentence)
# Out:
# ['First', 'off', ',', 'male', 'user', 'here', '.', 'I', 'have', 'purchased', 'all', 'the', 'colors', 'offered', 'and', 'other', 'sofishie', 'panties', 'and', 'these', 'are', 'by', 'far', 'my', 'favorite', '.', 'The', 'fit', 'is', 'perfect', ',', 'I', 'ordered', 'medium', 'and', 'I', 'have', 'a', '32', '”', 'waist', '.', 'I', 'love', 'the', 'quality', ',', 'how', 'they', 'feel', 'and', 'how', 'they', 'make', 'my', 'ass', 'look', '.', 'Totally', 'recommend.Sexy', 'look', ',', 'but', 'didn', '’', 't', 'notice', 'the', 'brand', 'until', 'she', 'shouted', 'it', 'from', 'the', 'bathroom', ',', 'LOL', '.', 'Whoever', 'named', 'this', 'product', 'had', 'one', 'job', 'and', 'failed', 'miserably', '!', 'Hahahaha', '“', 'So', 'fishie', '”', 'isn', '’', 't', 'exactly', 'a', 'thought', 'you', 'wan', 'na', 'associate', 'with', 'women', '’', 's', 'undies', '.', 'Just', 'saying', '...', '...', 'These', 'are', 'really', 'cute', 'and', 'sexy', '.', 'I', 'wouldn', '’', 't', 'wear', 'them', 'every', 'day', 'but', 'as', 'a', 'sexy', 'date', 'night', 'panty', 'they', 'work', 'well', '.', 'The', 'lace', 'is', 'elastic-y', 'and', 'feels', 'like', 'it', 'could', 'rip', 'with', 'rough', 'handling', ',', 'but', 'I', '’', 'm', 'not', 'sure', 'what', 'else', 'you', '’', 'd', 'expect', 'with', 'all', 'over', 'lace', 'panties.I', 'have', 'a', '32', '”', 'waist', 'and', '45', '”', 'hips', '.', 'I', 'wear', '12/14', 'jeans', 'and', 'the', 'large', 'fits', 'but', 'is', 'just', 'a', 'bit', 'too', 'tight', '.', 'An', 'XL', 'might', 'fit', 'a', 'little', 'better', ',', 'but', 'I', 'have', 'a', 'similar', 'pair', 'from', 'the', 'same', 'brand', 'and', 'the', 'XL', 'is', 'just', 'on', 'the', 'loose', 'side.The', 'shape', 'of', 'these', 'panties', 'is', 'very', 'flattering', ',', 'though', 'they', 'gap', 'in', 'a', 'strange', 'place', 'because', 'the', 'criss-cross', 'in', 'the', 'back', 'is', 'a', 'teensy', 'bit', 'loose', '.', 'They', "'re", 'awkward', 'to', 'keep', 'up', ',', 'but', 'I', 'like', 'the', 'way', 'they', 'look', 'and', 'the', 'price', 'was', 'too', 'good', 'to', 'resist', '.', 'Boyfriend', 'loves', "'em", ',', 'of', 'course.I', 'ordered', 'the', 'small', 'no', 'we', '’', 're', 'did', 'it', 'day', 'runs', 'big', 'or', 'give', 'a', 'number', 'size', 'to', 'match', 'they', 'were', 'very', 'big', 'more', 'like', 'at', 'least', 'a', 'medium', 'wanted', 'them', 'for', 'a', 'trip', 'so', 'was', 'disappointedThese', 'panties', 'are', 'so', 'beautiful', '!', 'However', 'I', 'wear', 'a', 'small', 'and', 'ordered', 'a', 'small', 'and', 'this', 'was', 'definitely', 'more', 'a', 'm', 'or', 'a', 'm/l', '.', 'I', '’', 'm', 'sure', 'that', 'one', 'of', 'my', 'friends', 'with', 'a', 'bugger', 'butt', 'than', 'me', 'we', 'will', 'enjoy', 'them', 'when', 'I', 'gift', 'it', 'to', 'themVery', 'sexy', 'and', 'nice', 'material', '.', 'Was', 'surprised', 'it', 'was', 'a', 'lil', 'big.Product', 'is', 'really', 'sexy', 'but', 'a', 'lil', 'on', 'the', 'big', 'side..', 'Ordered', 'a', 'small', 'and', 'fits', 'like', 'a', 'large..', 'Maybe', 'for', 'a', 'lil', 'bigger', 'woman', 'this', 'product', 'would', 'fit', 'niceGood', 'ass-ortmentI', '’', 'm', 'kind', 'of', 'a', 'Victoria', 'Secret', 'snob', ',', 'but', 'I', 'took', 'a', 'chance', 'and', 'ordered', 'the', '20', 'pack', 'of', 'undies', '.', 'One', 'of', 'my', 'best', 'purchases', 'on', 'Amazon', 'to', 'date', '!', 'I', 'received', 'a', 'variety', 'of', 'colors/materials', 'and', 'they', 'honestly', 'exceeded', 'my', 'expectations', '.', 'There', 'are', 'only', 'a', 'few', 'pair', 'that', 'I', '’', 'm', 'not', 'crazy', 'about', ',', 'but', 'that', '’', 's', 'pretty', 'good', 'for', 'not', 'having', 'personally', 'selected', 'them', '.', 'For', 'reference', 'I', 'ordered', 'a', 'L', ',', 'I', '’', 'm', '5', '’', '7', '”', 'and', 'around', '180', 'lbs', '(', 'hourglass', ')', 'and', 'I', 'wear', 'a', 'size', '10', 'jean.Some', 'of', 'the', 'numeric', 'sizing', 'is', 'weird', 'on', 'the', 'tags', ',', 'but', 'like', 'the', 'de ...
# ['First', 'male', 'user', 'purchased', 'colors', 'offered', 'sofishie', 'panties', 'far', 'favorite', 'fit', 'perfect', 'ordered', 'medium', '32', '”', 'waist', 'love', 'quality', 'feel', 'make', 'ass', 'look', 'Totally', 'recommend.Sexy', 'look', 'notice', 'brand', 'shouted', 'bathroom', 'LOL', 'Whoever', 'named', 'product', 'one', 'job', 'failed', 'miserably', 'Hahahaha', '“', 'So', 'fishie', '”', 'exactly', 'thought', 'wan', 'na', 'associate', 'women', 'undies', 'Just', 'saying', 'These', 'really', 'cute', 'sexy', 'wear', 'every', 'day', 'sexy', 'date', 'night', 'panty', 'work', 'well', 'lace', 'elastic-y', 'feels', 'like', 'could', 'rip', 'rough', 'handling', 'sure', 'else', 'expect', 'lace', 'panties.I', '32', '”', 'waist', '45', '”', 'hips', 'wear', '12/14', 'jeans', 'large', 'fits', 'bit', 'tight', 'An', 'XL', 'might', 'fit', 'little', 'better', 'similar', 'pair', 'brand', 'XL', 'loose', 'side.The', 'shape', 'panties', 'flattering', 'though', 'gap', 'strange', 'place', 'criss-cross', 'back', 'teensy', 'bit', 'loose', 'They', "'re", 'awkward', 'keep', 'like', 'way', 'look', 'price', 'good', 'resist', 'Boyfriend', 'loves', "'em", 'course.I', 'ordered', 'small', 'day', 'runs', 'big', 'give', 'number', 'size', 'match', 'big', 'like', 'least', 'medium', 'wanted', 'trip', 'disappointedThese', 'panties', 'beautiful', 'However', 'wear', 'small', 'ordered', 'small', 'definitely', 'm/l', 'sure', 'one', 'friends', 'bugger', 'butt', 'enjoy', 'gift', 'themVery', 'sexy', 'nice', 'material', 'Was', 'surprised', 'lil', 'big.Product', 'really', 'sexy', 'lil', 'big', 'side..', 'Ordered', 'small', 'fits', 'like', 'large..', 'Maybe', 'lil', 'bigger', 'woman', 'product', 'would', 'fit', 'niceGood', 'ass-ortmentI', 'kind', 'Victoria', 'Secret', 'snob', 'took', 'chance', 'ordered', '20', 'pack', 'undies', 'One', 'best', 'purchases', 'Amazon', 'date', 'received', 'variety', 'colors/materials', 'honestly', 'exceeded', 'expectations', 'There', 'pair', 'crazy', 'pretty', 'good', 'personally', 'selected', 'For', 'reference', 'ordered', 'L', '7', '”', 'around', '180', 'lbs', 'hourglass', 'wear', 'size', '10', 'jean.Some', 'numeric', 'sizing', 'weird', 'tags', 'like', 'description', 'says', 'ignore', 'They', 'seem', 'size', 'Will', 'purchase', 'Pics', 'included', '125lbs', 'wear', '4/5', 'pants', 'pretty', 'much', 'halfway', 'size', 'Small', 'tight', 'Medium', 'big', 'ordered', 'panty', 'size', 'Small', 'probably', 'ordered', 'medium', 'happy', 'purchase', 'They', 'adorable', 'plan', 'purchase', 'again.I', 'bought', 'items', 'based', 'almost', 'entirely', 'positive', 'reviews', 'seemed', 'fair', 'leave', ':', 'received', 'panties', '11', 'pairs', 'promptly', 'arrived', 'neatly', 'laid', 'reusable', 'plastic', 'pouch', 'All', 'pairs', 'thongs', 'g-strings', ';', 'unlike', 'reviewers', 'received', 'boy', 'shorts', 'bikinis', 'Every', 'pair', 'sized', 'well', 'ordered', '2xl', '9', 'usual', '8', 'even', 'little', 'loose', 'pair', 'two', 'seller', 'definitely', 'paying', 'attention', 'actual', 'listed', 'size.I', 'purchased', 'mainly', 'hubby', 'sudden', 'desire', 'see', 'g', 'decade', 'liking', 'styles', 'And', 'order', 'disappoint', 'liked', '10/11', 'pairs', 'even', 'last', 'pair', 'cute', 'little', 'bright', 'There', 'pair', 'really', 'lovely', 'black', 'lace', 'g', 'couple', 'matching', 'lace', 'thongs', 'different', 'colors', 'panties', 'adorable', 'see-through', 'pair', 'white', 'black', 'butterflies', 'several', 'cute', 'lacey', 'pairs.I', 'absolutely', 'order', 'pack', 'maybe', 'even', 'trying', 'different', 'styles.Thanks', 'seller', 'great', 'variety', 'fit', 'big', 'girl', '4', 'weigh', '215', 'ordered', 'extra', 'large', 'pretty', 'big', 'could', 'gotten', 'away', 'large', 'But', 'variety', 'quality', 'absolutely', 'loved', 'So', 'many', 'pretty', 'colors', 'different', 'styles', 'got', '2', 'duplicates', 'mind', 'all.Definitely', 'wide', 'variety', 'patterns', 'colors', 'styles', 'second', 'picture', 'shows', 'There', 'everything', 'real', ...

# %%
#  Word Frequency Statistics
counts = {}
for i in filtered_sentence:
    counts[i] = counts.get(i,0) + 1

    
counts
# Out:
# {'First': 12,
#  'male': 5,
#  'user': 1,
#  'purchased': 116,
#  'colors': 265,
#  'offered': 10,
#  'sofishie': 2,
#  'panties': 509,
#  'far': 56,
#  'favorite': 41,
#  'fit': 1092,
#  'perfect': 258,
#  'ordered': 531,
#  'medium': 274,
#  '32': 12,
#  '”': 125,
#  'waist': 184,
#  'love': 405,
#  'quality': 324,
#  'feel': 258,
#  'make': 115,
#  'ass': 12,
#  'look': 301,
#  'Totally': 3,
#  'recommend.Sexy': 1,
#  'notice': 17,
#  'brand': 51,
#  'shouted': 1,
#  'bathroom': 5,
#  'LOL': 3,
#  'Whoever': 1,
#  'named': 2,
#  'product': 139,
#  'one': 390,
#  'job': 17,
#  'failed': 1,
#  'miserably': 2,
#  'Hahahaha': 1,
#  '“': 50,
#  'So': 137,
#  'fishie': 1,
#  'exactly': 80,
#  'thought': 81,
#  'wan': 2,
#  'na': 16,
#  'associate': 1,
#  'women': 60,
#  'undies': 118,
#  'Just': 56,
#  'saying': 18,
#  'These': 238,
#  'really': 452,
#  'cute': 343,
#  'sexy': 415,
#  'wear': 679,
#  'every': 61,
#  'day': 95,
#  'date': 20,
#  'night': 50,
#  'panty': 148,
#  'work': 98,
#  'well': 419,
#  'lace': 433,
#  'elastic-y': 1,
#  'feels': 84,
#  'like': 827,
#  'could': 179,
#  'rip': 19,
#  'rough': 11,
#  'handling': 1,
#  'sure': 115,
#  'else': 24,
#  'expect': 42,
#  'panties.I': 3,
#  '45': 9,
#  'hips': 130,
#  '12/14': 6,
#  'jeans': 75,
#  'large': 336,
#  'fits': 260,
#  'bit': 234,
#  'tight': 172,
#  'An': 3,
#  'XL': 144,
#  'might': 59,
#  'little': 373,
#  'better': 114,
#  'similar': 28,
#  'pair': 224,
#  'loose': 81,
#  'side.The': 1,
#  'shape': 68,
#  'flattering': 81,
#  'though': 102,
#  'gap': 3,
#  'strange': 4,
#  'place': 43,
#  'criss-cross': 2,
#  'back': 219,
#  'teensy': 1,
#  'They': 675,
#  "'re": 215,
#  'awkward': 10,
#  'keep': 64,
#  'way': 187,
#  'price': 216,
#  'good': 377,
#  'resist': 1,
#  'Boyfriend': 2,
#  'loves': 45,
#  "'em": 1,
#  'course.I': 1,
#  'small': 603,
#  'runs': 27,
#  'big': 214,
#  'give': 101,
#  'number': 6,
#  'size': 1164,
#  'match': 7,
#  'least': 35,
#  'wanted': 107,
#  'trip': 12,
#  'disappointedThese': 1,
#  'beautiful': 86,
#  'However': 66,
#  'definitely': 171,
#  'm/l': 1,
#  'friends': 12,
#  'bugger': 1,
#  'butt': 121,
#  'enjoy': 13,
#  'gift': 43,
#  'themVery': 1,
#  'nice': 297,
#  'material': 309,
#  'Was': 8,
#  'surprised': 54,
#  'lil': 10,
#  'big.Product': 1,
#  'side..': 1,
#  'Ordered': 17,
#  'large..': 1,
#  'Maybe': 16,
#  'bigger': 67,
#  'woman': 31,
#  'would': 554,
#  'niceGood': 1,
#  'ass-ortmentI': 1,
#  'kind': 66,
#  'Victoria': 41,
#  'Secret': 46,
#  'snob': 2,
#  'took': 39,
#  'chance': 13,
#  '20': 29,
#  'pack': 103,
#  'One': 33,
#  'best': 67,
#  'purchases': 2,
#  'Amazon': 57,
#  'received': 101,
#  'variety': 34,
#  'colors/materials': 1,
#  'honestly': 23,
#  'exceeded': 1,
#  'expectations': 4,
#  'There': 75,
#  'crazy': 8,
#  'pretty': 293,
#  'personally': 7,
#  'selected': 4,
#  'For': 61,
#  'reference': 35,
#  'L': 29,
#  '7': 66,
#  'around': 167,
#  '180': 5,
#  'lbs': 104,
#  'hourglass': 2,
#  '10': 52,
#  'jean.Some': 1,
#  'numeric': 1,
#  'sizing': 77,
#  'weird': 29,
#  'tags': 17,
#  'description': 27,
#  'says': 52,
#  'ignore': 4,
#  'seem': 50,
#  'Will': 55,
#  'purchase': 113,
#  'Pics': 1,
#  'included': 12,
#  '125lbs': 4,
#  '4/5': 4,
#  'pants': 110,
#  'much': 240,
#  'halfway': 1,
#  'Small': 14,
#  'Medium': 35,
#  'probably': 75,
#  'happy': 131,
#  'adorable': 20,
#  'plan': 29,
#  'again.I': 12,
#  'bought': 258,
#  'items': 33,
#  'based': 36,
#  'almost': 56,
#  'entirely': 7,
#  'positive': 7,
#  'reviews': 161,
#  'seemed': 21,
#  'fair': 4,
#  'leave': 17,
#  ':': 207,
#  '11': 9,
#  'pairs': 73,
#  'promptly': 3,
#  'arrived': 37,
#  'neatly': 7,
#  'laid': 3,
#  'reusable': 1,
#  'plastic': 8,
#  'pouch': 5,
#  'All': 25,
#  'thongs': 139,
#  'g-strings': 2,
#  ';': 77,
#  'unlike': 4,
#  'reviewers': 15,
#  'boy': 18,
#  'shorts': 36,
#  'bikinis': 16,
#  'Every': 4,
#  'sized': 45,
#  '2xl': 8,
#  '9': 39,
#  'usual': 23,
#  '8': 77,
#  'even': 226,
#  'two': 121,
#  'seller': 27,
#  'paying': 14,
#  'attention': 9,
#  'actual': 17,
#  'listed': 6,
#  'size.I': 12,
#  'mainly': 2,
#  'hubby': 10,
#  'sudden': 1,
#  'desire': 1,
#  'see': 120,
#  'g': 8,
#  'decade': 1,
#  'liking': 3,
#  'styles': 17,
#  'And': 124,
#  'order': 232,
#  'disappoint': 2,
#  'liked': 57,
#  '10/11': 1,
#  'last': 89,
#  'bright': 30,
#  'lovely': 9,
#  'black': 73,
#  'couple': 44,
#  'matching': 15,
#  'different': 127,
#  'see-through': 7,
#  'white': 61,
#  'butterflies': 1,
#  'several': 31,
#  'lacey': 5,
#  'pairs.I': 2,
#  'absolutely': 66,
#  'maybe': 52,
#  'trying': 36,
#  'styles.Thanks': 1,
#  'great': 431,
#  'girl': 25,
#  '4': 130,
#  'weigh': 33,
#  '215': 3,
#  'extra': 56,
#  'gotten': 22,
#  'away': 43,
#  'But': 148,
#  'loved': 70,
#  'many': 45,
#  'got': 286,
#  '2': 143,
#  'duplicates': 11,
#  'mind': 17,
#  'all.Definitely': 1,
#  'wide': 42,
#  'patterns': 21,
#  'second': 35,
#  'picture': 91,
#  'shows': 19,
#  'everything': 63,
#  'real': 23,
#  'G': 6,
#  'string': 36,
#  'cuts': 6,
#  'thick': 45,
#  'band': 116,
#  'along': 19,
#  'pictured': 45,
#  'already': 49,
#  'worn': 57,
#  'comfortable': 560,
#  'pinstripe': 1,
#  'gray': 14,
#  'pink': 43,
#  '56': 1,
#  '140-145': 1,
#  'pounds': 56,
#  'usually': 217,
#  '5-6': 2,
#  'hips/jeans': 1,
#  'package': 61,
#  'figured': 24,
#  'gamble': 5,
#  'reading': 20,
#  'right': 177,
#  'Some': 23,
#  'larger': 105,
#  'others': 45,
#  'stretch': 110,
#  'hate': 21,
#  'underwear': 445,
#  'Great': 74,
#  'revamp': 1,
#  'indie': 2,
#  'drawer': 5,
#  'Overall': 41,
#  'consider': 10,
#  'recommend.I': 5,
#  'shop': 8,
#  'VS': 52,
#  '``': 114,
#  'buy': 237,
#  '30': 12,
#  'bucks': 4,
#  'deals': 2,
#  'admittedly': 1,
#  'costly': 1,
#  'years': 35,
#  'go': 151,
#  '&': 98,
#  'trouble': 7,
#  'finding': 18,
#  'After': 23,
#  'hopping': 1,
#  'amazon': 27,
#  '-': 199,
#  'found': 61,
#  'gave': 38,
#  'shot': 2,
#  'came': 103,
#  'house': 15,
#  'quickly': 16,
#  'boring': 4,
#  'fun': 49,
#  'care': 27,
#  'style': 103,
#  'overall': 32,
#  'What': 13,
#  'deal': 46,
#  'No': 54,
#  'mold/mildew': 1,
#  'smell': 24,
#  'people': 32,
#  'previously': 4,
#  'reported': 1,
#  "'ll": 65,
#  'ordering': 86,
#  '6': 107,
#  '135': 9,
#  'Not': 119,
#  'snug': 65,
#  'loose.I': 1,
#  'time': 189,
#  'Since': 11,
#  'brands': 26,
#  'smaller': 108,
#  'enough': 153,
#  'recommend': 157,
#  'normally': 86,
#  'may': 66,
#  'picked': 17,
#  'tried': 80,
#  'looked': 78,
#  'reason': 24,
#  'four': 10,
#  'stars': 45,
#  'PERFECTLY': 6,
#  'mean': 35,
#  'nature': 2,
#  'sort': 19,
#  'grab': 10,
#  'bag': 55,
#  'item': 58,
#  'think': 156,
#  'fantastic': 22,
#  'receive': 8,
#  'highly': 35,
#  "'ve": 133,
#  'told': 8,
#  'Cute': 15,
#  'everyday': 17,
#  'flimsy': 20,
#  'tear': 14,
#  'Regardless': 1,
#  'straps': 102,
#  'still': 167,
#  'chubby': 5,
#  'stomach.I': 1,
#  '3': 103,
#  '170': 14,
#  '12-14': 5,
#  'looks': 173,
#  'better.Bought': 7,
#  'raffle': 1,
#  'game': 12,
#  'bachelorette': 10,
#  'party': 19,
#  'everyone': 19,
#  'asking': 3,
#  'from.Very': 1,
#  'Fit': 30,
#  'Bottom': 6,
#  'top': 260,
#  'strappy': 4,
#  'part': 66,
#  'slightly': 33,
#  'also': 190,
#  'felt': 47,
#  'extended': 2,
#  'high': 144,
#  'Like': 24,
#  'waisted': 55,
#  'cut': 127,
#  'Still': 26,
#  'comfy': 159,
#  'part.This': 1,
#  'described': 24,
#  'ad': 5,
#  'Would': 30,
#  'friends.These': 1,
#  'tons': 2,
#  'Sofishie': 3,
#  'Sexy': 13,
#  'designs': 13,
#  'cost': 8,
#  'get': 272,
#  'Quality': 10,
#  'sexySuper': 1,
#  'Product': 2,
#  'wife': 64,
#  'said': 107,
#  'amazing': 75,
#  'secret': 9,
#  'owned': 10,
#  '10/10': 3,
#  'without': 83,
#  'knowing': 3,
#  'September': 1,
#  '15th': 1,
#  'correction': 1,
#  'update': 12,
#  'With': 12,
#  'hopes': 10,
#  'help': 34,
#  'someone': 30,
#  'according': 17,
#  'chart': 65,
#  'posted': 3,
#  '*should*': 1,
#  'To': 12,
#  'silly': 3,
#  'becuase': 1,
#  'straight': 7,
#  'supposed': 34,
#  '27': 5,
#  'inch': 22,
#  'skewed': 1,
#  'ok': 23,
#  'My': 145,
#  'hip': 39,
#  'circumference': 1,
#  '39': 7,
#  'inches': 19,
#  'biggest': 12,
#  'super': 192,
#  'comfortable-': 1,
#  'perfectly': 193,
#  'stretching': 1,
#  'fine': 83,
#  'since': 109,
#  'experienced': 5,
#  'rolling': 16,
#  'falling': 24,
#  'anything': 68,
#  'worried': 41,
#  'show': 70,
#  'case': 19,
#  'Even': 13,
#  'body': 77,
#  'hugging': 3,
#  'outfits': 10,
#  'ca': 51,
#  'plus': 34,
#  'color': 159,
#  'This': 179,
#  'steal': 3,
#  'compared': 16,
#  '20-30': 2,
#  'dollar': 8,
#  'department': 7,
#  'stores': 20,
#  'btw': 2,
#  'heck': 4,
#  'dang': 3,
#  'expensive': 27,
#  '?': 88,
#  'updated': 2,
#  'less': 33,
#  'confusing.The': 1,
#  'mentioned': 8,
#  'decided': 54,
#  'spot': 11,
#  'saw': 24,
#  'running': 12,
#  'went': 83,
#  'want': 142,
#  'backhand': 1,
#  'thinking': 13,
#  'getting': 47,
#  'design': 50,
#  'She': 40,
#  'them.These': 1,
#  'worthy': 2,
#  '5/5': 1,
#  'IF': 2,
#  'judging': 1,
#  'If': 135,
#  'follow': 7,
#  'manufacturer': 7,
#  'pleasantly': 17,
#  'M': 42,
#  'equivalent': 2,
#  'US': 35,
#  'S.': 4,
#  'Your': 1,
#  'waistline': 7,
#  '22.0': 1,
#  '27.5': 3,
#  'narrow': 7,
#  'booty': 31,
#  'As': 37,
#  'dislike': 5,
#  'full': 50,
#  'bottom': 75,
#  'bunch': 8,
#  'fabric': 157,
#  'ready': 13,
#  'target': 6,
#  'hike': 1,
#  'crack.I': 1,
#  'star': 27,
#  'lacy': 31,
#  'beauty': 1,
#  'completely': 36,
#  'seamless': 32,
#  'clothes': 60,
#  'front': 129,
#  'situation': 5,
#  'double-lined': 1,
#  'reverse': 1,
#  'stitching': 15,
#  'seams': 39,
#  'sewn': 28,
#  'inside': 18,
#  'creates': 3,
#  'unflattering': 9,
#  'bulky': 3,
#  'outline': 1,
#  'fitted': 8,
#  'That': 35,
#  'makes': 77,
#  'whole': 20,
#  'point': 20,
#  '‘': 7,
#  'counter': 1,
#  'productive.Overall': 1,
#  'regret': 8,
#  'flowy': 14,
#  'dresses/skirts': 1,
#  'fitting': 39,
#  'Hope': 12,
#  'review': 66,
#  'helps.The': 1,
#  'soft': 391,
#  'appeared': 3,
#  'made': 232,
#  'cheaply': 17,
#  'either': 49,
#  'thankfully': 3,
#  'read': 39,
#  'previous': 5,
#  'take': 37,
#  'heed': 1,
#  'warnings': 1,
#  '6.5': 3,
#  '130': 22,
#  "'junk": 1,
#  'trunk': 6,
#  'terms': 5,
#  'Usually': 13,
#  'occasional': 5,
#  'depending': 14,
#  'xlarge': 1,
#  'quite': 59,
#  'shocking': 2,
#  'advice': 4,
#  'sizes': 125,
#  'would.quality': 1,
#  'elastic': 92,
#  'soon': 37,
#  'totally': 23,
#  'sent': 23,
#  'instead': 63,
#  'LARGE': 1,
#  'coverage': 55,
#  'area': 56,
#  'low': 59,
#  'need': 88,
#  'XL.I': 3,
#  ',150': 1,
#  'followed': 15,
#  'stretched': 12,
#  'pinching': 7,
#  'creating': 7,
#  'visible': 13,
#  'dent': 1,
#  'skin': 48,
#  "'d": 95,
#  'say': 100,
#  'roomy': 5,
#  'lay': 8,
#  'flat': 31,
#  'somewhere': 8,
#  'scratchy': 41,
#  'Its': 11,
#  'smooth': 43,
#  'vibrant': 8,
#  'tip': 3,
#  'size-tags': 1,
#  'immediately': 8,
#  'worst': 5,
#  'paper': 3,
#  'tag': 45,
#  'huge': 32,
#  'otherwise': 13,
#  'Other': 15,
#  'washed': 95,
#  'know': 80,
#  'loving': 5,
#  'Very': 143,
#  'pantie': 18,
#  'lines': 63,
#  'Love': 67,
#  'feeling': 30,
#  'uncomfortable': 64,
#  'thong': 105,
#  'Colors': 3,
#  'true': 131,
#  'online': 48,
#  'echo': 1,
#  'size.Surprisingly': 1,
#  'wrong': 41,
#  'note': 16,
#  'explains': 2,
#  'alarmed': 1,
#  'colors.These': 1,
#  'hilarious': 1,
#  'actually': 120,
#  'butts': 1,
#  'lolI': 4,
#  'returning': 23,
#  '.this': 1,
#  'box': 27,
#  'cheap': 71,
#  'poor': 11,
#  'worth': 57,
#  'it.This': 5,
#  'Buyer': 1,
#  'beware': 2,
#  'buying': 104,
#  'novelty': 1,
#  'come': 83,
#  'box.I': 1,
#  'print': 16,
#  'add': 15,
#  'include': 4,
#  'knew': 25,
#  'unboxed': 1,
#  'Thank': 13,
#  'god': 1,
#  'gag': 5,
#  'joke': 7,
#  'something': 85,
#  'bride': 7,
#  'worn.I': 1,
#  'curious': 4,
#  'literally': 20,
#  'anyone': 39,
#  '4-holed-': 1,
#  'sake': 2,
#  'laughs': 1,
#  'giggles': 1,
#  'Valentine': 6,
#  'Day': 8,
#  'ripped': 26,
#  'guess': 41,
#  'win-win': 1,
#  'specifically': 8,
#  'paid': 17,
#  'dollars': 4,
#  'b/c': 3,
#  'advertised': 9,
#  'funny': 3,
#  'images': 7,
#  'wearing': 197,
#  'clear': 4,
#  'impressed': 30,
#  'OK.The': 1,
#  'purpose': 10,
#  'Get': 5,
#  'laughter': 2,
#  'Well': 14,
#  'Giving': 1,
#  'met': 3,
#  'confusion': 2,
#  'nobody': 2,
#  'knows': 5,
#  'Ok': 3,
#  'useless': 3,
#  'packaging': 11,
#  'picture.I': 2,
#  'partner': 7,
#  'able': 44,
#  'conduct': 1,
#  'physical': 2,
#  'activity': 3,
#  'held': 20,
#  'pull': 26,
#  'lot': 93,
#  'kinky': 2,
#  'these.This': 5,
#  'hit': 9,
#  'HILARIOUS': 1,
#  'DONT': 1,
#  'WASTE': 3,
#  'YOUR': 2,
#  'MONEY': 3,
#  'LOOK': 3,
#  'STIFF': 1,
#  'skinny': 14,
#  'person': 26,
#  '117': 2,
#  'mid': 4,
#  '33': 6,
#  'lower': 26,
#  '34.5': 1,
#  'SO': 21,
#  'DISAPPOINTED': 1,
#  'considering': 19,
#  'WALMARTThese': 1,
#  'looking': 124,
#  'run': 123,
#  'thankful': 1,
#  'more.Was': 1,
#  'going': 119,
#  'fishy': 1,
#  'man': 22,
#  'glad': 46,
#  'softest': 8,
#  'Nothing': 5,
#  'rolls': 17,
#  'bunches': 1,
#  'scallops': 1,
#  'boyshorts': 3,
#  'caused': 2,
#  'sweat': 1,
#  'never': 60,
#  'Definitely': 55,
#  'brand.These': 2,
#  'prettySo': 1,
#  'behind': 21,
#  'ur': 5,
#  'mineGirlfriend': 1,
#  'lasted': 6,
#  'washes.Fish': 1,
#  'net': 6,
#  'crotch': 56,
#  'nylon': 18,
#  'Yuck': 1,
#  'husband': 79,
#  'cared': 1,
#  'lingerie': 130,
#  'bat': 1,
#  'eye': 5,
#  'new': 47,
#  'walked': 1,
#  'living': 3,
#  'room': 24,
#  'chased': 1,
#  'bedroom': 6,
#  'struggling': 1,
#  'first': 113,
#  'child': 6,
#  'months': 37,
#  'ago': 28,
#  'hug': 12,
#  'curves': 14,
#  'compliment': 7,
#  'putting': 21,
#  'mature': 1,
#  'details': 9,
#  'ugly': 16,
#  'neon': 2,
#  'prints': 5,
#  'them.Very': 2,
#  'doesnt': 10,
#  'dig': 30,
#  'Feels': 8,
#  'nothing': 47,
#  'torrid': 1,
#  '16': 28,
#  'Charlotte': 1,
#  'Russell': 1,
#  'xl/xxl': 1,
#  'complaint': 17,
#  'strip': 4,
#  'overs': 2,
#  'lady': 22,
#  'bits': 10,
#  'half': 25,
#  'wider': 10,
#  'bug': 1,
#  'is.Very': 1,
#  'fast': 20,
#  'shipping': 13,
#  'them.I': 4,
#  'hesitant': 18,
#  'due': 27,
#  'upset': 7,
#  'underwear..': 1,
#  'upsized': 1,
#  'except': 16,
#  'fact': 20,
#  'longer': 32,
#  'bad..': 1,
#  'simple': 12,
#  'fix': 9,
#  'thread': 9,
#  'becomes': 3,
#  'annoying..': 1,
#  'thinner': 4,
#  'side': 84,
#  'expecting': 26,
#  'long..': 1,
#  '15': 10,
#  '$': 86,
#  'terrible': 15,
#  'marks': 4,
#  'multiple': 7,
#  'washesThese': 1,
#  'In': 22,
#  'past': 22,
#  'always': 88,
#  'played': 2,
#  'safe': 18,
#  '150': 8,
#  'medium.These': 3,
#  'You': 59,
#  'walking': 12,
#  'comes': 50,
#  'everyday.I': 1,
#  'durable': 34,
#  'stretchy': 124,
#  'expected': 144,
#  'goes': 17,
#  'itThese': 1,
#  '160..': 1,
#  'Ordering': 3,
#  'L.': 7,
#  'things': 52,
#  'especially': 42,
#  'comfortably': 34,
#  '110': 6,
#  'appear': 8,
#  'decent': 12,
#  'bum': 11,
#  'present': 6,
#  'odd': 10,
#  'When': 29,
#  'dug': 7,
#  'pinched': 2,
#  'choose': 9,
#  'binding': 7,
#  'curvy': 25,
#  'toCute': 1,
#  'falls': 9,
#  'apart': 45,
#  'hand': 26,
#  'wash': 130,
#  'even.Let': 1,
#  'honest': 17,
#  'quality.If': 1,
#  'Don': 11,
#  'spend': 11,
#  'tho.If': 1,
#  'store': 31,
#  'find': 145,
#  'sold': 9,
#  'morally': 1,
#  'sound': 5,
#  'retailer': 1,
#  'earth.Super': 1,
#  'boyfriend': 43,
#  'initially': 9,
#  'skeptical': 9,
#  'importantly': 1,
#  'next': 28,
#  'riding': 16,
#  'worked': 19,
#  'that.Very': 1,
#  'delicate': 24,
#  'Husband': 11,
#  'washing': 56,
#  'mesh': 12,
#  'garment': 16,
#  'write': 17,
#  'obligated': 2,
#  'striking': 1,
#  'suspicion': 1,
#  'fake': 4,
#  'happend': 1,
#  'luck': 12,
#  '24': 5,
#  'matter': 14,
#  'pick': 9,
#  'put': 83,
#  'smalls': 8,
#  'sending': 2,
#  'clearly': 5,
#  'Also': 40,
#  '80s': 2,
#  'keeping': 12,
#  'fond': 1,
#  'REEK': 1,
#  'dye': 3,
#  'toxic': 1,
#  'fumes': 1,
#  'tossing': 3,
#  'buys': 2,
#  'wasting': 3,
#  'money': 56,
#  'cotton': 194,
#  'teen': 3,
#  'although': 17,
#  'pricey': 5,
#  'realizing': 1,
#  'it.First': 1,
#  '25': 5,
#  'bad': 70,
#  'whatever': 10,
#  '21': 3,
#  'did.I': 2,
#  'small..': 1,
#  '5ft': 9,
#  '110lbs': 4,
#  'helps': 18,
#  'any.I': 1,
#  'mixed': 3,
#  'granny': 26,
#  'panties..': 1,
#  'describe': 9,
#  'ACTUALLY': 4,
#  'READ': 2,
#  'THE': 15,
#  'DESCRIPTION': 1,
#  '—': 5,
#  'truly': 23,
#  'TOO': 9,
#  'FREAKING': 1,
#  ...}

# %%
word_counts = list(counts.items())
#print(word_counts)

word_counts.sort(key = lambda x:x[1],reverse = True)  # 按词频降序排列

# output
for i in word_counts[0:50]:
    print(i)
# Out:
# ('size', 1164)
# ('fit', 1092)
# ('like', 827)
# ('wear', 679)
# ('They', 675)
# ('small', 603)
# ('comfortable', 560)
# ('would', 554)
# ('ordered', 531)
# ('panties', 509)
# ('really', 452)
# ('underwear', 445)
# ('lace', 433)
# ('great', 431)
# ('well', 419)
# ('sexy', 415)
# ('love', 405)
# ('soft', 391)
# ('one', 390)
# ('good', 377)
# ('little', 373)
# ('cute', 343)
# ('large', 336)
# ('quality', 324)
# ('bra', 312)
# ('material', 309)
# ('look', 301)
# ('nice', 297)
# ('pretty', 293)
# ('got', 286)
# ('medium', 274)
# ('get', 272)
# ('colors', 265)
# ('fits', 260)
# ('top', 260)
# ('perfect', 258)
# ('feel', 258)
# ('bought', 258)
# ('much', 240)
# ('These', 238)
# ('buy', 237)
# ('bit', 234)
# ('order', 232)
# ('made', 232)
# ('even', 226)
# ('pair', 224)
# ('back', 219)
# ('usually', 217)
# ('price', 216)
# ("'re", 215)

# %%
from scipy.misc import imread
import matplotlib.pyplot as plt
import jieba
from wordcloud import WordCloud, ImageColorGenerator

# %%
path_img ="C:\\Users\\sxw17\\Desktop\\DATA\\data analysis\\sexy panties in Amazon\\word_cloud\\love.jpg"
bg_pic = imread(path_img)


wordcloud = WordCloud(mask=bg_pic, background_color='black', scale=10).generate(text)

image_colors = ImageColorGenerator(bg_pic)

plt.imshow(wordcloud)
plt.axis('off')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
