# %% [markdown]
# # 2.04 Aggregations: Min, Max, and Everything In Between

# %% [markdown]
# ## Summing the Values in an Array

# %%
import numpy as np

# %%
L = np.random.random(100)
L
# Out:
# array([ 0.45417251,  0.79197646,  0.77602011,  0.64775491,  0.95894705,
#         0.80899436,  0.51342723,  0.57382298,  0.810365  ,  0.84714682,
#         0.49231432,  0.1678601 ,  0.55101275,  0.75911715,  0.86245186,
#         0.16991739,  0.71088929,  0.00823211,  0.68484774,  0.44204987,
#         0.14881297,  0.23995049,  0.87050472,  0.55371584,  0.93159748,
#         0.82362494,  0.964505  ,  0.97619028,  0.66858931,  0.33788649,
#         0.44870713,  0.22107722,  0.15701215,  0.31148258,  0.53242705,
#         0.62581194,  0.79053115,  0.73791269,  0.89183832,  0.35677175,
#         0.19910697,  0.67524138,  0.87472289,  0.58297831,  0.22543106,
#         0.45056413,  0.13447364,  0.44947976,  0.90153339,  0.9198587 ,
#         0.26878522,  0.8674165 ,  0.53219382,  0.09350192,  0.95787452,
#         0.53562592,  0.46452077,  0.20822395,  0.53828903,  0.02376032,
#         0.78801804,  0.68945533,  0.34728802,  0.86980236,  0.47001218,
#         0.46491837,  0.42357245,  0.65105445,  0.53487191,  0.16668209,
#         0.62654851,  0.74732965,  0.12560474,  0.1649446 ,  0.92051923,
#         0.20961353,  0.0414256 ,  0.88205223,  0.45846163,  0.04612708,
#         0.34232022,  0.96078141,  0.86708626,  0.00277267,  0.57174973,
#         0.33340426,  0.94337293,  0.17346636,  0.06130606,  0.84031908,
#         0.61301378,  0.80887505,  0.85173495,  0.80710079,  0.11722684,
#         0.26397936,  0.52390265,  0.75230554,  0.97283022,  0.8252641 ])

# %%
sum(L)
# Out:
# 54.784965937790922

# %%
np.sum(L)
# Out:
# 54.784965937790936

# %%
big_array = np.random.rand(1000000)
# %timeit sum(big_array)
# %timeit np.sum(big_array)
# Out:
# 10 loops, best of 3: 130 ms per loop
# 1000 loops, best of 3: 855 µs per loop

# %% [markdown]
# ## Minimum and Maximum

# %%
big_array
# Out:
# array([ 0.93521298,  0.60067731,  0.96734565, ...,  0.6073724 ,
#         0.6996371 ,  0.36754226])

# %%
min(big_array), max(big_array)
# Out:
# (1.5129913120137672e-06, 0.99999813194662679)

# %%
np.min(big_array), np.max(big_array)
# Out:
# (1.5129913120137672e-06, 0.99999813194662679)

# %%
# %timeit min(big_array)
# %timeit np.min(big_array)
# Out:
# 10 loops, best of 3: 48.7 ms per loop
# 1000 loops, best of 3: 375 µs per loop

# %% [markdown]
# ### Multi dimensional aggregates¶

# %%
M = np.random.random((3, 4))
print(M)
# Out:
# [[ 0.39842507  0.85839903  0.77534771  0.5227448 ]
#  [ 0.91609253  0.64846004  0.7669808   0.12800202]
#  [ 0.00728905  0.99817897  0.7283943   0.05923343]]

# %%
M.sum()
# Out:
# 6.8075477604617856

# %%
M.min(axis=0)
# Out:
# array([ 0.00728905,  0.64846004,  0.7283943 ,  0.05923343])

# %%
M.max(axis=1)
# Out:
# array([ 0.85839903,  0.91609253,  0.99817897])

# %% [markdown]
# ![Capture.PNG](attachment:Capture.PNG)

# %%
import pandas as pd
data = pd.read_csv('president_heights.csv')
data

data['height(cm)'].values.tolist()
# Out:
# [189,
#  170,
#  189,
#  163,
#  183,
#  171,
#  185,
#  168,
#  173,
#  183,
#  173,
#  173,
#  175,
#  178,
#  183,
#  193,
#  178,
#  173,
#  174,
#  183,
#  183,
#  168,
#  170,
#  178,
#  182,
#  180,
#  183,
#  178,
#  182,
#  188,
#  175,
#  179,
#  183,
#  193,
#  182,
#  183,
#  177,
#  185,
#  188,
#  188,
#  182,
#  185]

# %%
heights = np.array(data['height(cm)'])
print(heights)
# Out:
# [189 170 189 163 183 171 185 168 173 183 173 173 175 178 183 193 178 173
#  174 183 183 168 170 178 182 180 183 178 182 188 175 179 183 193 182 183
#  177 185 188 188 182 185]

# %%
print("Mean height:       ", heights.mean())
print("Standard deviation:", heights.std())
print("Minimum height:    ", heights.min())
print("Maximum height:    ", heights.max())
# Out:
# Mean height:        179.738095238
# Standard deviation: 6.93184344275
# Minimum height:     163
# Maximum height:     193

# %%
# important 

print("25th percentile:   ", np.percentile(heights, 25))
print("Median:            ", np.median(heights))
print("75th percentile:   ", np.percentile(heights, 75))
# Out:
# 25th percentile:    174.25
# Median:             182.0
# 75th percentile:    183.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()  # set plot style

# %%
plt.hist(heights)
plt.title('Height Distribution of US Presidents')
plt.xlabel('height (cm)')
plt.ylabel('number');
