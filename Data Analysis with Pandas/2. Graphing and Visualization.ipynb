# %%
import pandas as pd 
df= pd.read_csv("avocado.csv")
    
albany_df = df[df["region"]=="Albany"]

albany_set = albany_df.set_index("Date")

# %matplotlib inline
albany_set["AveragePrice"].plot()

# %%
df["Date"]= pd.to_datetime(df["Date"])

print(df.head())
# Out:
#    Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0           0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4 2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# ...

# %%
albany_set["AveragePrice"].rolling(25).mean().plot()

# %%
albany_set.head(25)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
# 2015-11-22           5          1.26      55979.78  1184.27   48067.99
# 2015-11-15           6          0.99      83453.76  1368.92   73672.72
# 2015-11-08           7          0.98     109428.33   703.75  101815.36
# 2015-11-01           8          1.02      99811.42  1022.15   87315.57
# 2015-10-25           9          1.07      74338.76   842.40   64757.44
# 2015-10-18          10          1.12      84843.44   924.86   75595.85
# 2015-10-11          11          1.28      64489.17  1582.03   52677.92
# ...

# %%
albany_set.index
# some dates mess up 
# so it needs to be reordered
# Out:
# Index(['2015-12-27', '2015-12-20', '2015-12-13', '2015-12-06', '2015-11-29',
#        '2015-11-22', '2015-11-15', '2015-11-08', '2015-11-01', '2015-10-25',
#        ...
#        '2018-03-11', '2018-03-04', '2018-02-25', '2018-02-18', '2018-02-11',
#        '2018-02-04', '2018-01-28', '2018-01-21', '2018-01-14', '2018-01-07'],
#       dtype='object', name='Date', length=338)

# %%
albany_set.sort_index(inplace=True)
albany_set["AveragePrice"].rolling(25).mean().plot()

# %%
albany_set["price25ma"]=albany_set["AveragePrice"].rolling(25).mean()

# %%
albany_set.head(10)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225    4770  \
# Date
# 2015-01-04          51          1.22      40873.28  2819.50  28287.42   49.90
# 2015-01-04          51          1.79       1373.95    57.42    153.88    0.00
# 2015-01-11          50          1.24      41195.08  1002.85  31640.34  127.12
# 2015-01-11          50          1.77       1182.56    39.00    305.12    0.00
# 2015-01-18          49          1.17      44511.28   914.14  31540.32  135.77
# 2015-01-18          49          1.93       1118.47     8.02    178.78    0.00
# 2015-01-25          48          1.06      45147.50   941.38  33196.16  164.14
# 2015-01-25          48          1.89       1115.89    14.87    148.72    0.00
# 2015-02-01          47          0.99      70873.60  1353.90  60017.20  179.32
# 2015-02-01          47          1.83       1228.51    33.12     99.36    0.00
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# ...

# %%
albany_set.tail(10)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2018-02-25           4          1.28     104278.89  10368.77   59723.32
# 2018-02-25           4          1.56       5356.63    816.56     532.59
# 2018-03-04           3          1.08     139520.60  12002.12  105069.57
# 2018-03-04           3          1.48       3851.30    311.55     296.77
# 2018-03-11           2          1.12     144648.75  15823.35  110950.68
# 2018-03-11           2          1.68       2570.52    131.67     229.56
# 2018-03-18           1          1.66       3154.45    275.89     297.96
# 2018-03-18           1          1.35     105304.65  13234.86   61037.58
# 2018-03-25           0          1.57     149396.50  16361.69  109045.03
# 2018-03-25           0          1.71       2321.82     42.95     272.41
#
#              4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2018-02-25  48.00    34138.80    30126.31     3702.49       310.00
# ...

# %%
albany_set.dropna()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2015-03-29          39          1.93       1082.44     24.75     173.26
# 2015-03-29          39          1.02      67799.08   1402.28   58623.22
# 2015-04-05          38          1.16      47362.13    961.77   35577.66
# 2015-04-05          38          1.93       1526.10     15.75     202.52
# 2015-04-12          37          1.76       1634.59     51.75      93.38
# 2015-04-12          37          1.13      48364.29    864.27   30374.15
# 2015-04-19          36          1.96       1516.24     18.01     102.45
# 2015-04-19          36          1.19      49064.73    774.15   33941.51
# 2015-04-26          35          1.22      49585.46    875.65   35841.75
# 2015-04-26          35          1.90        929.61     27.01      30.53
# 2015-05-03          34          1.20      59197.67    919.87   45490.05
# 2015-05-03          34          2.03       1798.99     57.93     130.62
# ...

# %%
albany_df=df.copy()[df["region"]=="Albany"]
albany_df.set_index("Date", inplace=True)
albany_df.sort_index(inplace=True)
albany_df["price25ma"]= albany_df['AveragePrice'].rolling(25).mean()

# %%
df.values
# Out:
# array([[0, '2015-12-27', 1.33, ..., 'conventional', 2015, 'Albany'],
#        [1, '2015-12-20', 1.35, ..., 'conventional', 2015, 'Albany'],
#        [2, '2015-12-13', 0.93, ..., 'conventional', 2015, 'Albany'],
#        ...,
#        [9, '2018-01-21', 1.87, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [10, '2018-01-14', 1.93, ..., 'organic', 2018, 'WestTexNewMexico'],
#        [11, '2018-01-07', 1.62, ..., 'organic', 2018, 'WestTexNewMexico']], dtype=object)

# %%
df['region'].values
# Out:
# array(['Albany', 'Albany', 'Albany', ..., 'WestTexNewMexico',
#        'WestTexNewMexico', 'WestTexNewMexico'], dtype=object)

# %%
df['region'].values.tolist()
# Out:
# ['Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Albany',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
#  'Atlanta',
# ...

# %%
set(df['region'].values.tolist())
# Out:
# {'Albany',
#  'Atlanta',
#  'BaltimoreWashington',
#  'Boise',
#  'Boston',
#  'BuffaloRochester',
#  'California',
#  'Charlotte',
#  'Chicago',
#  'CincinnatiDayton',
#  'Columbus',
#  'DallasFtWorth',
#  'Denver',
#  'Detroit',
#  'GrandRapids',
#  'GreatLakes',
#  'HarrisburgScranton',
#  'HartfordSpringfield',
#  'Houston',
#  'Indianapolis',
#  'Jacksonville',
#  'LasVegas',
#  'LosAngeles',
#  'Louisville',
#  'MiamiFtLauderdale',
#  'Midsouth',
#  'Nashville',
#  'NewOrleansMobile',
#  'NewYork',
#  'Northeast',
#  'NorthernNewEngland',
#  'Orlando',
#  'Philadelphia',
#  'PhoenixTucson',
#  'Pittsburgh',
#  'Plains',
#  'Portland',
#  'RaleighGreensboro',
#  'RichmondNorfolk',
#  'Roanoke',
#  'Sacramento',
#  'SanDiego',
#  'SanFrancisco',
#  'Seattle',
#  'SouthCarolina',
#  'SouthCentral',
#  'Southeast',
#  'Spokane',
#  'StLouis',
#  'Syracuse',
#  'Tampa',
#  'TotalUS',
#  'West',
#  'WestTexNewMexico'}

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork', 'Northeast',
#        'NorthernNewEngland', 'Orlando', 'Philadelphia', 'PhoenixTucson',
#        'Pittsburgh', 'Plains', 'Portland', 'RaleighGreensboro',
#        'RichmondNorfolk', 'Roanoke', 'Sacramento', 'SanDiego',
#        'SanFrancisco', 'Seattle', 'SouthCarolina', 'SouthCentral',
#        'Southeast', 'Spokane', 'StLouis', 'Syracuse', 'Tampa', 'TotalUS',
#        'West', 'WestTexNewMexico'], dtype=object)

# %%
graph_df = pd.DataFrame()

for region in df['region'].unique()[:16]:
    print(region)
    
    region_df=df.copy()[df['region']==region]
    
    region_df.set_index("Date", inplace=True)
    region_df.sort_index(inplace=True)
    
    name=str(region)+"price25ma'"
    region_df[name] = region_df["AveragePrice"].rolling(25).mean()
    
    
    if graph_df.empty:
        graph_df=region_df[[name]]
    else:
        graph_df=graph_df.join(region_df[[name]])
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes

# %%
df.tail(3)
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046     4225  \
# 18246           9 2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
graph_df.tail()
# duplicate cases
# Out:
#             Albanyprice25ma'  Atlantaprice25ma'  \
# Date
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
#
#             BaltimoreWashingtonprice25ma'  Boiseprice25ma'  Bostonprice25ma'  \
# Date
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
#
#             BuffaloRochesterprice25ma'  Californiaprice25ma'  \
# Date
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
# ...

# %%
df=pd.read_csv('avocado.csv')

df = df.copy()[df['type']=="organic"]

df['Date']=pd.to_datetime(df['Date'])

df.sort_values(by="Date", ascending=True, inplace=True)

df.head(100)

graph_df = pd.DataFrame()

for region in df['region'].unique():
    print(region)
    
    region_df=df.copy()[df['region']==region]
    
    region_df.set_index("Date", inplace=True)
    region_df.sort_index(inplace=True)
    
    name=str(region)+"price25ma'"
    region_df[name] = region_df["AveragePrice"].rolling(25).mean()
    
    
    if graph_df.empty:
        graph_df=region_df[[name]]
    else:
        graph_df=graph_df.join(region_df[name])
    
graph_df.tail()
# Out:
# California
# LasVegas
# PhoenixTucson
# BuffaloRochester
# Spokane
# LosAngeles
# Philadelphia
# Boston
# StLouis
# Louisville
# Orlando
# Southeast
# Boise
# MiamiFtLauderdale
# NorthernNewEngland
# BaltimoreWashington
# Midsouth
# Tampa
# West
# Northeast
# Atlanta
# Nashville
# TotalUS
# Syracuse
# WestTexNewMexico
# Jacksonville
# Charlotte
# Sacramento
# GrandRapids
# Roanoke
# Denver
# SanDiego
# GreatLakes
# RichmondNorfolk
# DallasFtWorth
# SanFrancisco
# HarrisburgScranton
# Pittsburgh
# RaleighGreensboro
# Seattle
# HartfordSpringfield
# Portland
# CincinnatiDayton
# SouthCarolina
# Houston
# Chicago
# Plains
# Indianapolis
# SouthCentral
# Columbus
# Albany
# Detroit
# NewOrleansMobile
# NewYork
#             Californiaprice25ma'  LasVegasprice25ma'  PhoenixTucsonprice25ma'  \
# Date
# 2018-02-25                1.9128              1.9120                   1.7468
# 2018-03-04                1.8876              1.8748                   1.7404
# ...

# %%
graph_df.dropna().plot(figsize=(8,5), legend=False)
